# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
#import pixiedust
#!pip install --user --upgrade pixiedust

ml = pd.read_csv('merge_ab_chyl1.csv')
#ml = pd.read_csv('merge_ab_chyl1.csv', dtype = {'LENGTH_OF_CAR_OWNERSHIP': 'str'})
# reformat xBF character 
ml.rename(columns = {'﻿INSURANCE_POLICY_ID': 'INSURANCE_POLICY_ID'}, inplace = True)

#ml.dtypes
#ml.columns
pd.set_option('display.max_columns', None)
ml.head()
# Out:
#    INSURANCE_POLICY_ID  CUSTOMER_ID  NUMBER_OF_COMMUNICATIONS  GROSS_INCOME  \
# 0             10001830      1002372                         1         65370
# 1             10001831      1002373                         2         76152
# 2             10001832      1002374                         1         63863
# 3             10001833      1002375                         0         78256
# 4             10001834      1002376                         2         55635
#
#    AGE_OF_PARTY  CLAIMS_COUNT  CLAIMS_AMOUNT  NUMBER_OF_CLAIMS_DENIED  \
# 0            24             4            277                        4
# 1            27             3            287                        0
# 2            26             4            237                       17
# 3            25             1            391                        7
# 4            21             3            331                        2
#
#   EDUCATION_LEVEL EMPLOYMENT_STATUS GENDER MARITAL_STATUS  SENTIMENT_SCORE  \
# ...

# %%
col_sel = ['INSURANCE_POLICY_ID','NUMBER_OF_COMMUNICATIONS','GROSS_INCOME','CHURN']
ml_sel = ml.loc[:, col_sel]

#ml_sel.CHURN.astype('np.int')
ml_sel.dtypes
#ml_sel.head()
# Out:
# INSURANCE_POLICY_ID         int64
# NUMBER_OF_COMMUNICATIONS    int64
# GROSS_INCOME                int64
# CHURN                       int64
# dtype: object

# %%
# pixiedust display api call
display(ml_sel)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure561581e7" class="pd_save" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#                         <div>Too many data points to plot. Dropping 311 rows to make the chart more presentable.</div>
#
#
#         </div>

# %%
# %matplotlib inline
ml.groupby('EDUCATION_LEVEL').GROSS_INCOME.mean()
# Out:
# EDUCATION_LEVEL
# College         49149.545455
# Graduate        72721.030612
# High School     71875.135135
# PhD             61996.045455
# Professional    70072.086957
# Name: GROSS_INCOME, dtype: float64

# %%
# %matplotlib inline
ml.groupby('EDUCATION_LEVEL').GROSS_INCOME.mean().plot(kind = 'bar')
# kind = hist, pie, line, etc....

# %%
ml.AGE_OF_PARTY.value_counts()
# Out:
# 21    26
# 23    26
# 30    26
# 22    24
# 29    20
# 31    18
# 26    18
# 27    18
# 24    17
# 41    17
# 54    16
# 55    10
# 66     9
# 25     9
# 37     9
# 39     9
# 44     9
# 46     9
# 48     9
# 51     9
# 28     8
# 60     8
# 61     2
# 20     2
# 32     1
# 43     1
# 50     1
# Name: AGE_OF_PARTY, dtype: int64

# %%
# import Matplotlib (scientific plotting library)
import matplotlib.pyplot as plt

# allow plots to appear within the notebook
# %matplotlib inline

# plot the relationship (ONLY BETWEEN NUMERIC VALUES)
x = ml.AGE_OF_PARTY
y = ml.CHURN 

plt.plot(x, y)
plt.title('PRACTICE PLOTTING')
plt.xlabel('AGE')
plt.ylabel('CHURN')

# %%
# conventional way to import seaborn
import seaborn as sns

# allow plots to appear within the notebook
# %matplotlib inline

# visualize the relationship between the features and the response using scatterplots
sns.pairplot(ml, x_vars=['AGE_OF_PARTY','GROSS_INCOME'], y_vars='CHURN', size=7, aspect=0.7, kind='reg')

# %%
mf = pd.read_csv('/gpfs/global_fs01/sym_shared/YPProdSpark/user/scc8-d44aeb3f7d9dd3-674d31d66b72/notebook/work/merged_ab.csv')
mf.shape
# Out:
# (331, 39)

# %%
# %ls -l
# Out:
# total 480
# -rw------- 1 scc8-d44aeb3f7d9dd3-674d31d66b72 users 64526 Aug  7 12:53 merge_ab_chyl1.csv
# -rw------- 1 scc8-d44aeb3f7d9dd3-674d31d66b72 users 64526 Aug 11 08:26 merged_ab.csv
# -rw------- 1 scc8-d44aeb3f7d9dd3-674d31d66b72 users 27474 Aug 14 10:46 test.png

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('PRACTICE SINE CURVE')
plt.grid(True)
plt.savefig("test.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 35, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('IQ Range')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import pylab
x = np.linspace(0, 20, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

pylab.plot(x, y1, '-b', label='sine')
pylab.plot(x, y2, '-r', label='cosine')
pylab.legend(loc='upper right')
pylab.ylim(-1.5, 2.0)
# Out:
# (-1.5, 2.0)
