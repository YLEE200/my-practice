# %%
### sample JSON object

data = [{'state': 'Florida',
         'shortname': 'FL',
         'info': {
             'governor': 'Rick Scott'
                 },
        'counties': [{'name': 'Dade', 'population': 12345},
                    {'name': 'Broward', 'population': 40000},
                    {'name': 'Palm Beach', 'population': 60000}]},
        
        {'state': 'Ohio',
        'shortname': 'OH',
        'info': {
              'governor': 'John Kasich'
                  },
         'counties': [{'name': 'Summit', 'population': 1234},
                    {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
from pandas.io.json import json_normalize

result = json_normalize(data, 'counties', ['state', 'shortname', 
                                           ['info', 'governor']])

result
# Out:
#          name  population info.governor    state shortname
# 0        Dade       12345    Rick Scott  Florida        FL
# 1     Broward       40000    Rick Scott  Florida        FL
# 2  Palm Beach       60000    Rick Scott  Florida        FL
# 3      Summit        1234   John Kasich     Ohio        OH
# 4    Cuyahoga        1337   John Kasich     Ohio        OH

# %%
data1 =  [ 
          {'color': 'red',
          'value': '2000'
          },
        
          {'color': 'green',
           'value': '3000'
          }
         ]

# %%
import pandas as pd
import json

#data = json.loads(data1)
data2 = json.dumps(data1)

df = pd.read_json(data2)
df
# Out:
#    color  value
# 0    red   2000
# 1  green   3000

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json

#r = pd.read_json('data1')

r = json_normalize(data1)

r
# Out:
#    color value
# 0    red  2000
# 1  green  3000

# %%
### from jsonplaceholder website - developer website for test REST APIs with dummy JSON data
import json, requests
import pandas as pd

url = 'https://jsonplaceholder.typicode.com/posts'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text, parse_constant='utf-8')
myjson
# Out:
# [{u'body': u'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto',
#   u'id': 1,
#   u'title': u'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   u'userId': 1},
#  {u'body': u'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla',
#   u'id': 2,
#   u'title': u'qui est esse',
#   u'userId': 1},
#  {u'body': u'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut',
#   u'id': 3,
#   u'title': u'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   u'userId': 1},
# ...

# %%
print json.dumps(r.text, indent=4, sort_keys=True)
# Out:
# "[\n  {\n    \"userId\": 1,\n    \"id\": 1,\n    \"title\": \"sunt aut facere repellat provident occaecati excepturi optio reprehenderit\",\n    \"body\": \"quia et suscipit\\nsuscipit recusandae consequuntur expedita et cum\\nreprehenderit molestiae ut ut quas totam\\nnostrum rerum est autem sunt rem eveniet architecto\"\n  },\n  {\n    \"userId\": 1,\n    \"id\": 2,\n    \"title\": \"qui est esse\",\n    \"body\": \"est rerum tempore vitae\\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\\nqui aperiam non debitis possimus qui neque nisi nulla\"\n  },\n  {\n    \"userId\": 1,\n    \"id\": 3,\n    \"title\": \"ea molestias quasi exercitationem repellat qui ipsa sit aut\",\n    \"body\": \"et iusto sed quo iure\\nvoluptatem occaecati omnis eligendi aut ad\\nvoluptatem doloribus vel accusantium quis pariatur\\nmolestiae porro eius odio et labore et velit aut\"\n  },\n  {\n    \"userId\": 1,\n    \"id\":
# ...

# %%
from pandas.io.json import json_normalize
r = json_normalize(myjson, ['title'],['body', 'userId'])
r
# Out:
#       0                                               body  userId
# 0     s  quia et suscipit\nsuscipit recusandae consequu...       1
# 1     u  quia et suscipit\nsuscipit recusandae consequu...       1
# 2     n  quia et suscipit\nsuscipit recusandae consequu...       1
# 3     t  quia et suscipit\nsuscipit recusandae consequu...       1
# 4        quia et suscipit\nsuscipit recusandae consequu...       1
# 5     a  quia et suscipit\nsuscipit recusandae consequu...       1
# 6     u  quia et suscipit\nsuscipit recusandae consequu...       1
# 7     t  quia et suscipit\nsuscipit recusandae consequu...       1
# 8        quia et suscipit\nsuscipit recusandae consequu...       1
# 9     f  quia et suscipit\nsuscipit recusandae consequu...       1
# 10    a  quia et suscipit\nsuscipit recusandae consequu...       1
# 11    c  quia et suscipit\nsuscipit recusandae consequu...       1
# 12    e  quia et suscipit\nsuscipit recusandae consequu...       1
# ...
